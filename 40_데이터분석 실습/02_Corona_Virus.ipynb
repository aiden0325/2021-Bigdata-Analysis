# %% [markdown]
# # 2. 코로나 바이러스

# %% [markdown]
# ## 2-1. 문제 정의 및 가설 수립
# * 국가별 코로나 바이러스 확진자 통계
# * 미국의 확진자가 가장 많을 것이다.

# %% [markdown]
# ### 2-2. 데이터 가져오기

# %%
# !kaggle datasets download -d imdevskp/corona-virus-report
# Out:
# corona-virus-report.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !mkdir corona_data
# Out:
# 하위 디렉터리 또는 파일 corona_data이(가) 이미 있습니다.

# %%
# !tar -xvf corona-virus-report.zip -C corona_data
# Out:
# x country_wise_latest.csv
# x covid_19_clean_complete.csv
# x day_wise.csv
# x full_grouped.csv
# x usa_county_wise.csv
# x worldometer_data.csv

# %% [markdown]
# ## 2-3. 데이터 로드하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('corona_data/covid_19_clean_complete.csv')
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %% [markdown]
# ## 2-4. 데이터 살펴보기

# %%
df.shape
# Out:
# (49068, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df['Country/Region'].value_counts()
# Out:
# China             6204
# Canada            2256
# United Kingdom    2068
# France            2068
# Australia         1504
#                   ...
# Panama             188
# Egypt              188
# Madagascar         188
# Monaco             188
# South Sudan        188
# Name: Country/Region, Length: 187, dtype: int64

# %%
df['Date'].min(), df['Date'].max()
# Out:
# ('2020-01-22', '2020-07-27')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %%
df.columns = ['지역', '국가', '위도', '경도', '일자', '확진자', '사망자', '회복자', '치료중', 'WHO']
df.head()
# Out:
#     지역           국가        위도         경도         일자  확진자  사망자  회복자  치료중  \
# 0  NaN  Afghanistan  33.93911  67.709953 2020-01-22    0    0    0    0
# 1  NaN      Albania  41.15330  20.168300 2020-01-22    0    0    0    0
# 2  NaN      Algeria  28.03390   1.659600 2020-01-22    0    0    0    0
# 3  NaN      Andorra  42.50630   1.521800 2020-01-22    0    0    0    0
# 4  NaN       Angola -11.20270  17.873900 2020-01-22    0    0    0    0
#
#                      WHO
# 0  Eastern Mediterranean
# 1                 Europe
# 2                 Africa
# 3                 Europe
# 4                 Africa

# %% [markdown]
# ## 2-5. EDA(탐색적 데이터 분석)

# %% [markdown]
# ### 1. 대한민국 코로나 데이터 분석

# %%
df[df['국가'].str.contains('Korea')]
# Out:
#         지역           국가         위도          경도         일자    확진자  사망자    회복자  \
# 141    NaN  South Korea  35.907757  127.766922 2020-01-22      1    0      0
# 402    NaN  South Korea  35.907757  127.766922 2020-01-23      1    0      0
# 663    NaN  South Korea  35.907757  127.766922 2020-01-24      2    0      0
# 924    NaN  South Korea  35.907757  127.766922 2020-01-25      2    0      0
# 1185   NaN  South Korea  35.907757  127.766922 2020-01-26      3    0      0
# ...    ...          ...        ...         ...        ...    ...  ...    ...
# 47904  NaN  South Korea  35.907757  127.766922 2020-07-23  13979  298  12817
# 48165  NaN  South Korea  35.907757  127.766922 2020-07-24  14092  298  12866
# 48426  NaN  South Korea  35.907757  127.766922 2020-07-25  14150  298  12890
# 48687  NaN  South Korea  35.907757  127.766922 2020-07-26  14175  299  12905
# 48948  NaN  South Korea  35.907757  127.766922 2020-07-27  14203  300  13007
#
#        치료중              WHO
# 141      1  Western Pacific
# 402      1  Western Pacific
# 663      2  Western Pacific
# 924      2  Western Pacific
# 1185     3  Western Pacific
# ...    ...              ...
# 47904  864  Western Pacific
# 48165  928  Western Pacific
# 48426  962  Western Pacific
# 48687  971  Western Pacific
# 48948  896  Western Pacific
#
# [188 rows x 10 columns]

# %%
koreaDF = df[df['국가'] =='South Korea']
koreaDF
# Out:
#         지역           국가         위도          경도         일자    확진자  사망자    회복자  \
# 141    NaN  South Korea  35.907757  127.766922 2020-01-22      1    0      0
# 402    NaN  South Korea  35.907757  127.766922 2020-01-23      1    0      0
# 663    NaN  South Korea  35.907757  127.766922 2020-01-24      2    0      0
# 924    NaN  South Korea  35.907757  127.766922 2020-01-25      2    0      0
# 1185   NaN  South Korea  35.907757  127.766922 2020-01-26      3    0      0
# ...    ...          ...        ...         ...        ...    ...  ...    ...
# 47904  NaN  South Korea  35.907757  127.766922 2020-07-23  13979  298  12817
# 48165  NaN  South Korea  35.907757  127.766922 2020-07-24  14092  298  12866
# 48426  NaN  South Korea  35.907757  127.766922 2020-07-25  14150  298  12890
# 48687  NaN  South Korea  35.907757  127.766922 2020-07-26  14175  299  12905
# 48948  NaN  South Korea  35.907757  127.766922 2020-07-27  14203  300  13007
#
#        치료중              WHO
# 141      1  Western Pacific
# 402      1  Western Pacific
# 663      2  Western Pacific
# 924      2  Western Pacific
# 1185     3  Western Pacific
# ...    ...              ...
# 47904  864  Western Pacific
# 48165  928  Western Pacific
# 48426  962  Western Pacific
# 48687  971  Western Pacific
# 48948  896  Western Pacific
#
# [188 rows x 10 columns]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x='일자', y='확진자', data=koreaDF)
sns.lineplot(x='일자', y='사망자', data=koreaDF)
sns.lineplot(x='일자', y='회복자', data=koreaDF)
plt.legend(['확진자수', '사망자수', '회복자수'])

# %% [markdown]
# ### 2. 국가별 코로나 데이터 분석

# %%
latestDF = df[df['일자'] == max(df['일자'])]
latestDF.head()
# Out:
#         지역           국가        위도         경도         일자    확진자   사망자    회복자  \
# 48807  NaN  Afghanistan  33.93911  67.709953 2020-07-27  36263  1269  25198
# 48808  NaN      Albania  41.15330  20.168300 2020-07-27   4880   144   2745
# 48809  NaN      Algeria  28.03390   1.659600 2020-07-27  27973  1163  18837
# 48810  NaN      Andorra  42.50630   1.521800 2020-07-27    907    52    803
# 48811  NaN       Angola -11.20270  17.873900 2020-07-27    950    41    242
#
#         치료중                    WHO
# 48807  9796  Eastern Mediterranean
# 48808  1991                 Europe
# 48809  7973                 Africa
# 48810    52                 Europe
# 48811   667                 Africa

# %%
sortedDF = latestDF.sort_values(by='확진자', ascending=False)
sortedDF.head(10)
# Out:
#         지역              국가         위도          경도         일자      확진자     사망자  \
# 49030  NaN              US  40.000000 -100.000000 2020-07-27  4290259  148011
# 48835  NaN          Brazil -14.235000  -51.925300 2020-07-27  2442375   87618
# 48936  NaN           India  20.593684   78.962880 2020-07-27  1480073   33408
# 48992  NaN          Russia  61.524010  105.318756 2020-07-27   816680   13334
# 49005  NaN    South Africa -30.559500   22.937500 2020-07-27   452529    7067
# 48963  NaN          Mexico  23.634500 -102.552800 2020-07-27   395489   44022
# 48986  NaN            Peru  -9.190000  -75.015200 2020-07-27   389717   18418
# 48854  NaN           Chile -35.675100  -71.543000 2020-07-27   347923    9187
# 49028  NaN  United Kingdom  55.378100   -3.436000 2020-07-27   300111   45759
# 48938  NaN            Iran  32.427908   53.688046 2020-07-27   293606   15912
#
#            회복자      치료중                    WHO
# 49030  1325804  2816444               Americas
# 48835  1846641   508116               Americas
# 48936   951166   495499        South-East Asia
# 48992   602249   201097                 Europe
# 49005   274925   170537                 Africa
# 48963   303810    47657               Americas
# 48986   272547    98752               Americas
# 48854   319954    18782               Americas
# 49028        0   254352                 Europe
# 48938   255144    22550  Eastern Mediterranean

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=45)
sns.barplot(x='국가', y='확진자', data=sortedDF.head(10))
# Out:
# <AxesSubplot:xlabel='국가', ylabel='확진자'>

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=45)
sns.barplot(x='국가', y='사망자', data=sortedDF.head(10))
# Out:
# <AxesSubplot:xlabel='국가', ylabel='사망자'>

# %%
globalDF = df.groupby('일자')[['확진자', '사망자', '회복자']].sum().reset_index()
globalDF.head()
# Out:
#           일자   확진자  사망자  회복자
# 0 2020-01-22   555   17   28
# 1 2020-01-23   654   18   30
# 2 2020-01-24   941   26   36
# 3 2020-01-25  1434   42   39
# 4 2020-01-26  2118   56   52

# %%
sns.lineplot(x='일자', y='확진자', data=globalDF)
sns.lineplot(x='일자', y='사망자', data=globalDF)
sns.lineplot(x='일자', y='회복자', data=globalDF)
# Out:
# <AxesSubplot:xlabel='일자', ylabel='확진자'>

# %% [markdown]
# ## 3. folium 사용하기
# * 파이썬 기반의 지도 시각화 라이브러리
# * https://github.com/python-visualization/folium

# %%
import folium
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a611d341c2954b559ffc85a061d32032%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a611d341c2954b559ffc85a061d32032%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a611d341c2954b559ffc85a061d32032%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a611d341c2954b559ffc85a061d32032%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
folium.CircleMarker(location=[1,1],radius=10).add_to(m)

# %%
latestDF.head()
# Out:
#         지역           국가        위도         경도         일자    확진자   사망자    회복자  \
# 48807  NaN  Afghanistan  33.93911  67.709953 2020-07-27  36263  1269  25198
# 48808  NaN      Albania  41.15330  20.168300 2020-07-27   4880   144   2745
# 48809  NaN      Algeria  28.03390   1.659600 2020-07-27  27973  1163  18837
# 48810  NaN      Andorra  42.50630   1.521800 2020-07-27    907    52    803
# 48811  NaN       Angola -11.20270  17.873900 2020-07-27    950    41    242
#
#         치료중                    WHO
# 48807  9796  Eastern Mediterranean
# 48808  1991                 Europe
# 48809  7973                 Africa
# 48810    52                 Europe
# 48811   667                 Africa

# %%
latestDF.loc[48807, '위도'], latestDF.loc[48807, '경도'], latestDF.loc[48807, '확진자']
# Out:
# (33.93911, 67.709953, 36263)

# %%
latestDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 48807 to 49067
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      78 non-null     object
#  1   국가      261 non-null    object
#  2   위도      261 non-null    float64
#  3   경도      261 non-null    float64
#  4   일자      261 non-null    datetime64[ns]
#  5   확진자     261 non-null    int64
#  6   사망자     261 non-null    int64
#  7   회복자     261 non-null    int64
#  8   치료중     261 non-null    int64
#  9   WHO     261 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 32.4+ KB

# %%
m = folium.Map(location=[0,0], zoom_start=2)
for n in latestDF.index:
    folium.CircleMarker(location=[latestDF.loc[n, '위도'], latestDF.loc[n,'경도']],radius=latestDF.loc[n, '확진자']/30000,color="red",fill="True",popup=latestDF.loc[n,'국가']+ ":" + str(latestDF.loc[n, '확진자'])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_19661d7b161e450399f1592ef9038f2b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_19661d7b161e450399f1592ef9038f2b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_19661d7b161e450399f1592ef9038f2b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_19661d7b161e450399f1592ef9038f2b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs% ...
